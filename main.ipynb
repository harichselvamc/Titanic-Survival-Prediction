# %% [markdown]
# ## Dataset Overview
#
# * survived : Survived (1) or DIED (0)
# * pclass   : Passenger's Class
# * name     : Passenger's Name
# * sex      : Passenger's Sex
# * age      : Passenger's Age
# * sibsp    : Number of Siblings/Spouses Abroad
# * parch    : Number of Parents / Children Abroad
# * ticket   : Ticket Number
# * fare     : Fare
# * cabin    : Cabin
# * embarked : Port of Embarkation

# %% [markdown]
# ## Importing Library

# %%
import numpy as np

#Data Preprocessing
import pandas as pd

#Data Visualization
import seaborn as sns
# %matplotlib inline
from matplotlib import pyplot as plt
from matplotlib import *

#Algorithm
from sklearn.linear_model import *
from sklearn.ensemble import *
from sklearn.tree import *
from sklearn.svm import *

# %% [markdown]
# # ALGORITHM
# * LogisticRegression
# * RandomForestClassifier
# * DecisionTreeClassifier
# * SVC,LinearSVC

# %% [markdown]
# # Load LIbraries

# %%
train_df=pd.read_csv("train.csv")
test_df=pd.read_csv("test.csv")

# %%
train_df
# Out:
#       pclass  survived                                               name  \
# 0        1.0       1.0   Mayne, Mlle. Berthe Antonine ("Mrs de Villiers")
# 1        1.0       0.0                           Warren, Mr. Frank Manley
# 2        2.0       1.0  Laroche, Mrs. Joseph (Juliette Marie Louise La...
# 3        2.0       0.0                           Bailey, Mr. Percy Andrew
# 4        1.0       0.0                             Astor, Col. John Jacob
# ...      ...       ...                                                ...
# 1043     3.0       0.0                     O'Sullivan, Miss. Bridget Mary
# 1044     3.0       0.0                    Pettersson, Miss. Ellen Natalia
# 1045     3.0       0.0                               Williams, Mr. Leslie
# 1046     3.0       1.0                             Heikkinen, Miss. Laina
# 1047     3.0       0.0                            Petranec, Miss. Matilda
#
#          sex   age  sibsp  parch            ticket      fare    cabin  \
# ...

# %%
test_df
# Out:
#      pclass  survived                                              name  \
# 0       3.0       0.0                                  Calic, Mr. Petar
# 1       3.0       0.0                           Mardirosian, Mr. Sarkis
# 2       2.0       1.0                         Brown, Miss. Edith Eileen
# 3       3.0       0.0                     Maenpaa, Mr. Matti Alexanteri
# 4       2.0       0.0                           Fox, Mr. Stanley Hubert
# ..      ...       ...                                               ...
# 257     1.0       1.0                          Mock, Mr. Philipp Edmund
# 258     1.0       0.0                       White, Mr. Percival Wayland
# 259     1.0       1.0                   Greenfield, Mr. William Bertram
# 260     3.0       0.0  Katavelas, Mr. Vassilios ("Catavelas Vassilios")
# 261     3.0       0.0                             Lyntakoff, Mr. Stanko
#
#         sex   age  sibsp  parch             ticket     fare    cabin embarked  \
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048 entries, 0 to 1047
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1047 non-null   float64
#  1   survived   1047 non-null   float64
#  2   name       1047 non-null   object
#  3   sex        1047 non-null   object
#  4   age        835 non-null    float64
#  5   sibsp      1047 non-null   float64
#  6   parch      1047 non-null   float64
#  7   ticket     1047 non-null   object
#  8   fare       1046 non-null   float64
#  9   cabin      232 non-null    object
#  10  embarked   1046 non-null   object
#  11  boat       375 non-null    object
#  12  body       103 non-null    float64
#  13  home.dest  591 non-null    object
# dtypes: float64(7), object(7)
# memory usage: 114.8+ KB

# %%
train_df.describe()
# Out:
#             pclass     survived         age        sibsp        parch  \
# count  1047.000000  1047.000000  835.000000  1047.000000  1047.000000
# mean      2.297994     0.370583   29.706587     0.499522     0.356256
# std       0.837132     0.483192   14.418489     0.985434     0.843441
# min       1.000000     0.000000    0.166700     0.000000     0.000000
# 25%       2.000000     0.000000   21.000000     0.000000     0.000000
# 50%       3.000000     0.000000   28.000000     0.000000     0.000000
# 75%       3.000000     1.000000   38.000000     1.000000     0.000000
# max       3.000000     1.000000   80.000000     8.000000     9.000000
#
#               fare        body
# count  1046.000000  103.000000
# mean     33.341821  161.291262
# std      51.858719   99.016599
# min       0.000000    1.000000
# 25%       7.895800   71.000000
# 50%      14.454200  165.000000
# 75%      31.206250  255.500000
# max     512.329200  328.000000

# %%
train_df.head()
# Out:
#    pclass  survived                                               name  \
# 0     1.0       1.0   Mayne, Mlle. Berthe Antonine ("Mrs de Villiers")
# 1     1.0       0.0                           Warren, Mr. Frank Manley
# 2     2.0       1.0  Laroche, Mrs. Joseph (Juliette Marie Louise La...
# 3     2.0       0.0                           Bailey, Mr. Percy Andrew
# 4     1.0       0.0                             Astor, Col. John Jacob
#
#       sex   age  sibsp  parch         ticket      fare    cabin embarked boat  \
# 0  female  24.0    0.0    0.0       PC 17482   49.5042      C90        C    6
# 1    male  64.0    1.0    0.0         110813   75.2500      D37        C  NaN
# 2  female  22.0    1.0    2.0  SC/Paris 2123   41.5792      NaN        C   14
# 3    male  18.0    0.0    0.0          29108   11.5000      NaN        S  NaN
# 4    male  47.0    1.0    0.0       PC 17757  227.5250  C62 C64        C  NaN
#
#     body                       home.dest
# ...

# %% [markdown]
# ## Null Value Check

# %%
total=train_df.isnull().sum().sort_values(ascending=False)
total
# Out:
# body         945
# cabin        816
# boat         673
# home.dest    457
# age          213
# fare           2
# embarked       2
# pclass         1
# survived       1
# name           1
# sex            1
# sibsp          1
# parch          1
# ticket         1
# dtype: int64

# %%
percentage_1=train_df.isnull().sum()/train_df.isnull().count()*100
percentage_1
# Out:
# pclass        0.095420
# survived      0.095420
# name          0.095420
# sex           0.095420
# age          20.324427
# sibsp         0.095420
# parch         0.095420
# ticket        0.095420
# fare          0.190840
# cabin        77.862595
# embarked      0.190840
# boat         64.217557
# body         90.171756
# home.dest    43.606870
# dtype: float64

# %%
 percentage_2=(round(percentage_1,1)).sort_values(ascending=False)
percentage_2
# Out:
# body         90.2
# cabin        77.9
# boat         64.2
# home.dest    43.6
# age          20.3
# fare          0.2
# embarked      0.2
# pclass        0.1
# survived      0.1
# name          0.1
# sex           0.1
# sibsp         0.1
# parch         0.1
# ticket        0.1
# dtype: float64

# %%
missing_data=pd.concat([total,percentage_2],axis=1,keys=['Total','%'])
missing_data
# Out:
#            Total     %
# body         945  90.2
# cabin        816  77.9
# boat         673  64.2
# home.dest    457  43.6
# age          213  20.3
# fare           2   0.2
# embarked       2   0.2
# pclass         1   0.1
# survived       1   0.1
# name           1   0.1
# sex            1   0.1
# sibsp          1   0.1
# parch          1   0.1
# ticket         1   0.1

# %%
train_df.columns.values
# Out:
# array(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch',
#        'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype=object)

# %% [markdown]
# ## Data Visualization

# %%
survived="Survived"
not_survived="Not Survived"

fig,axes=plt.subplots(nrows=1,ncols=2,figsize=(10,4))
men=train_df[train_df['sex']=='male']
women=train_df[train_df['sex']=='female']

ax=sns.distplot(men[men['survived']==1].age.dropna(),bins=18,label=survived,ax=axes[0],kde=False)
ax=sns.distplot(men[men['survived']==0].age.dropna(),bins=40,label=not_survived,ax=axes[0],kde=False)
ax.legend()
ax.set_title('male')

ax=sns.distplot(women[women['survived']==1].age.dropna(),bins=18,label=survived,ax=axes[1],kde=False)
ax=sns.distplot(women[women['survived']==0].age.dropna(),bins=40,label=not_survived,ax=axes[1],kde=False)
ax.legend()
ax.set_title('female')
# Out:
# C:\Users\haric\AppData\Local\Temp\ipykernel_20476\3297177934.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax=sns.distplot(men[men['survived']==1].age.dropna(),bins=18,label=survived,ax=axes[0],kde=False)
# C:\Users\haric\AppData\Local\Temp\ipykernel_20476\3297177934.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
facetgrid=sns.FacetGrid(train_df,row='embarked')
facetgrid.map(sns.pointplot,'pclass','survived','sex',palette=None,order=None,hue_order=None)
facetgrid.add_legend()

# %%
sns.barplot(x='pclass',y='survived',data=train_df)
# Out:
# <AxesSubplot: xlabel='pclass', ylabel='survived'>

# %%
data=[train_df,test_df]
for dataset in data:
    dataset['relatives']=dataset['sibsp']+dataset['parch']
    dataset.loc[dataset['relatives']>0,"not_alone"]=0
    dataset.loc[dataset['relatives']==0,"not_alone"]=1
    dataset['not_alone']=dataset['not_alone']
train_df['not_alone'].value_counts()
# Out:
# 1.0    636
# 0.0    411
# Name: not_alone, dtype: int64

# %%
import seaborn as sns
axes=sns.barplot(x='relatives',y='survived', data=train_df)

# %% [markdown]
# ## Data Preprocessing and Feature Engineering

# %%
train_df
# Out:
#       pclass  survived                                               name  \
# 0        1.0       1.0   Mayne, Mlle. Berthe Antonine ("Mrs de Villiers")
# 1        1.0       0.0                           Warren, Mr. Frank Manley
# 2        2.0       1.0  Laroche, Mrs. Joseph (Juliette Marie Louise La...
# 3        2.0       0.0                           Bailey, Mr. Percy Andrew
# 4        1.0       0.0                             Astor, Col. John Jacob
# ...      ...       ...                                                ...
# 1043     3.0       0.0                     O'Sullivan, Miss. Bridget Mary
# 1044     3.0       0.0                    Pettersson, Miss. Ellen Natalia
# 1045     3.0       0.0                               Williams, Mr. Leslie
# 1046     3.0       1.0                             Heikkinen, Miss. Laina
# 1047     3.0       0.0                            Petranec, Miss. Matilda
#
#          sex   age  sibsp  parch            ticket      fare    cabin  \
# ...

# %%
import re
deck = {"A": 1, "B": 2, "C": 3, "D": 4, "E": 5, "F": 6, "G": 7, "U": 8}
data = [train_df, test_df]

for dataset in data:
    dataset['cabin'] = dataset['cabin'].fillna("U0")  # Added the missing closing parenthesis
    dataset['Deck'] = dataset['cabin'].map(lambda x: re.compile("([a-zA-Z]+)").search(x).group())
    dataset['Deck'] = dataset['Deck'].map(deck)
    dataset['Deck'] = dataset['Deck'].fillna(0)
    dataset['Deck'] = dataset['Deck'].astype(int)

# We can now drop the cabin feature
train_df = train_df.drop(['cabin'], axis=1)
test_df = test_df.drop(['cabin'], axis=1)

# %%
train_df.head()
# Out:
#    pclass  survived                                               name  \
# 0     1.0       1.0   Mayne, Mlle. Berthe Antonine ("Mrs de Villiers")
# 1     1.0       0.0                           Warren, Mr. Frank Manley
# 2     2.0       1.0  Laroche, Mrs. Joseph (Juliette Marie Louise La...
# 3     2.0       0.0                           Bailey, Mr. Percy Andrew
# 4     1.0       0.0                             Astor, Col. John Jacob
#
#       sex   age  sibsp  parch         ticket      fare embarked boat   body  \
# 0  female  24.0    0.0    0.0       PC 17482   49.5042        C    6    NaN
# 1    male  64.0    1.0    0.0         110813   75.2500        C  NaN    NaN
# 2  female  22.0    1.0    2.0  SC/Paris 2123   41.5792        C   14    NaN
# 3    male  18.0    0.0    0.0          29108   11.5000        S  NaN    NaN
# 4    male  47.0    1.0    0.0       PC 17757  227.5250        C  NaN  124.0
#
#                         home.dest  relatives  not_alone  Deck
# ...

# %%
data = [train_df, test_df]

for dataset in data:
    mean_age = dataset["age"].mean()
    std_age = dataset["age"].std()
    is_null_age = dataset["age"].isnull().sum()

    # compute random numbers between the mean, std, and is_null
    rand_age = np.random.randint(mean_age - std_age, mean_age + std_age, size=is_null_age)

    # fill NaN values in Age column with random values generated
    age_slice = dataset["age"].copy()
    age_slice[np.isnan(age_slice)] = rand_age
    dataset["age"] = age_slice.astype(int)

# Verify if there are still any missing values in the "Age" column of the train_df
print("Missing values in train_df 'age' column after imputation:", train_df["age"].isnull().sum())
# Out:
# Missing values in train_df 'age' column after imputation: 0

# %%
train_df['embarked'].describe()
# Out:
# count     1046
# unique       3
# top          S
# freq       734
# Name: embarked, dtype: object

# %%
common_value='S'
data=[train_df,test_df]
for dataset in data:
    dataset['embarked']=dataset['embarked'].fillna(common_value)

# %%
train_df['embarked'].describe()
# Out:
# count     1048
# unique       3
# top          S
# freq       736
# Name: embarked, dtype: object

# %%
train_df['embarked'].isnull().sum()
# Out:
# 0

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048 entries, 0 to 1047
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1047 non-null   float64
#  1   survived   1047 non-null   float64
#  2   name       1047 non-null   object
#  3   sex        1047 non-null   object
#  4   age        1048 non-null   int32
#  5   sibsp      1047 non-null   float64
#  6   parch      1047 non-null   float64
#  7   ticket     1047 non-null   object
#  8   fare       1046 non-null   float64
#  9   embarked   1048 non-null   object
#  10  boat       375 non-null    object
#  11  body       103 non-null    float64
#  12  home.dest  591 non-null    object
#  13  relatives  1047 non-null   float64
#  14  not_alone  1047 non-null   float64
#  15  Deck       1048 non-null   int32
# dtypes: float64(8), int32(2), object(6)
# memory usage: 122.9+ KB

# %%
data=[train_df,test_df]
for dataset in data:
    dataset['fare']=dataset['fare'].fillna(0)
    dataset['fare']=dataset['fare'].astype(int)
    dataset['pclass']=dataset['pclass'].fillna(0)
    dataset['pclass']=dataset['pclass'].astype(int)
    dataset['survived']=dataset['survived'].fillna(0)
    dataset['survived']=dataset['survived'].astype(int)
    dataset['sibsp']=dataset['sibsp'].fillna(0)
    dataset['sibsp']=dataset['sibsp'].astype(int)
    dataset['parch']=dataset['parch'].fillna(0)
    dataset['parch']=dataset['parch'].astype(int)
    dataset['relatives']=dataset['relatives'].fillna(0)
    dataset['relatives']=dataset['relatives'].astype(int)
    dataset['not_alone']=dataset['not_alone'].fillna(0)
    dataset['not_alone']=dataset['not_alone'].astype(int)
    dataset['body']=dataset['body'].fillna(0)
    dataset['body']=dataset['body'].astype(int)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048 entries, 0 to 1047
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1048 non-null   int32
#  1   survived   1048 non-null   int32
#  2   name       1047 non-null   object
#  3   sex        1047 non-null   object
#  4   age        1048 non-null   int32
#  5   sibsp      1048 non-null   int32
#  6   parch      1048 non-null   int32
#  7   ticket     1047 non-null   object
#  8   fare       1048 non-null   int32
#  9   embarked   1048 non-null   object
#  10  boat       375 non-null    object
#  11  body       1048 non-null   int32
#  12  home.dest  591 non-null    object
#  13  relatives  1048 non-null   int32
#  14  not_alone  1048 non-null   int32
#  15  Deck       1048 non-null   int32
# dtypes: int32(10), object(6)
# memory usage: 90.2+ KB

# %%
import pandas as pd

data = [train_df, test_df]
titles = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Rare": 5}

for dataset in data:
    
    dataset['Title'] = dataset['name'].str.extract(' ([A-Za-z]+)\.', expand=False)
    dataset['Title'] = dataset['Title'].replace(['Lady', 'Countess', 'Capt', 'Col', 'Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Rare')
    dataset['Title'] = dataset['Title'].replace('Mlle', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Ms', 'Miss')
    dataset['Title'] = dataset['Title'].replace('Mme', 'Mrs')
    dataset['Title'] = dataset['Title'].map(titles)
    dataset['Title'] = dataset['Title'].fillna(0)
    dataset['Title']=dataset['Title'].astype(int)
    dataset.drop(['name'], axis=1, inplace=True)

# %%
train_df.head()
# Out:
#    pclass  survived     sex  age  sibsp  parch         ticket  fare embarked  \
# 0       1         1  female   24      0      0       PC 17482    49        C
# 1       1         0    male   64      1      0         110813    75        C
# 2       2         1  female   22      1      2  SC/Paris 2123    41        C
# 3       2         0    male   18      0      0          29108    11        S
# 4       1         0    male   47      1      0       PC 17757   227        C
#
#   boat  body                       home.dest  relatives  not_alone  Deck  \
# 0    6     0           Belgium  Montreal, PQ          0          1     3
# 1  NaN     0                    Portland, OR          1          0     4
# 2   14     0                   Paris / Haiti          3          0     8
# 3  NaN     0  Penzance, Cornwall / Akron, OH          0          1     8
# 4  NaN   124                    New York, NY          1          0     3
#
#    Title
# 0      2
# 1      1
# 2      3
# 3      1
# 4      5

# %%
genders = {"male": 0, "female": 1}
data = [train_df, test_df]

for dataset in data:
    dataset['sex'] = dataset['sex'].map(genders)
    dataset['sex'] = dataset['sex'].fillna(0)
    dataset['sex']=dataset['sex'].astype(int)

# %%
train_df['ticket'].describe()
# Out:
# count     1047
# unique     784
# top       1601
# freq         7
# Name: ticket, dtype: object

# %%
train_df=train_df.drop(['ticket'],axis=1)
test_df=test_df.drop(['ticket'],axis=1)

# %%
train_df
# Out:
#       pclass  survived  sex  age  sibsp  parch  fare embarked boat  body  \
# 0          1         1    1   24      0      0    49        C    6     0
# 1          1         0    0   64      1      0    75        C  NaN     0
# 2          2         1    1   22      1      2    41        C   14     0
# 3          2         0    0   18      0      0    11        S  NaN     0
# 4          1         0    0   47      1      0   227        C  NaN   124
# ...      ...       ...  ...  ...    ...    ...   ...      ...  ...   ...
# 1043       3         0    1   28      0      0     7        Q  NaN     0
# 1044       3         0    1   18      0      0     7        S  NaN     0
# 1045       3         0    0   28      0      0    16        S  NaN    14
# 1046       3         1    1   26      0      0     7        S  NaN     0
# 1047       3         0    1   28      0      0     7        S  NaN     0
#
#                            home.dest  relatives  not_alone  Deck  Title
# ...

# %%
data = [train_df, test_df]

for dataset in data:
    
    dataset.loc[dataset['age'] <= 11, 'age'] = 0
    dataset.loc[(dataset['age'] > 11) & (dataset['age'] <= 18), 'age'] = 1
    dataset.loc[(dataset['age'] > 18) & (dataset['age'] <= 22), 'age'] = 2
    dataset.loc[(dataset['age'] > 22) & (dataset['age'] <= 27), 'age'] = 3
    dataset.loc[(dataset['age'] > 27) & (dataset['age'] <= 33), 'age'] = 4
    dataset.loc[(dataset['age'] > 33) & (dataset['age'] <= 40), 'age'] = 5
    dataset.loc[(dataset['age'] > 40) & (dataset['age'] <= 66), 'age'] = 6
    dataset.loc[dataset['age'] > 66, 'age'] = 6

# Check the distribution in the training dataset
print(train_df['age'].value_counts())
# Out:
# 6    198
# 4    182
# 3    178
# 5    150
# 2    142
# 1    126
# 0     72
# Name: age, dtype: int64

# %%
data = [train_df, test_df]

for dataset in data:
    dataset.loc[dataset['fare'] <= 7.91, 'fare'] = 0
    dataset.loc[(dataset['fare'] > 7.91) & (dataset['fare'] <= 14.454), 'fare'] = 1
    dataset.loc[(dataset['fare'] > 14.454) & (dataset['fare'] <= 31), 'fare'] = 2
    dataset.loc[(dataset['fare'] > 31) & (dataset['fare'] <= 99), 'fare'] = 3
    dataset.loc[(dataset['fare'] > 99) & (dataset['fare'] <= 250), 'fare'] = 4
    dataset.loc[dataset['fare'] > 250, 'fare'] = 5

# %%
train_df
# Out:
#       pclass  survived  sex  age  sibsp  parch  fare embarked boat  body  \
# 0          1         1    1    3      0      0     3        C    6     0
# 1          1         0    0    6      1      0     3        C  NaN     0
# 2          2         1    1    2      1      2     3        C   14     0
# 3          2         0    0    1      0      0     1        S  NaN     0
# 4          1         0    0    6      1      0     4        C  NaN   124
# ...      ...       ...  ...  ...    ...    ...   ...      ...  ...   ...
# 1043       3         0    1    4      0      0     0        Q  NaN     0
# 1044       3         0    1    1      0      0     0        S  NaN     0
# 1045       3         0    0    4      0      0     2        S  NaN    14
# 1046       3         1    1    3      0      0     0        S  NaN     0
# 1047       3         0    1    4      0      0     0        S  NaN     0
#
#                            home.dest  relatives  not_alone  Deck  Title
# ...

# %%
train_df=train_df.drop(['home.dest'],axis=1)
test_df=test_df.drop(['home.dest'],axis=1)

# %%
train_df
# Out:
#       pclass  survived  sex  age  sibsp  parch  fare embarked boat  body  \
# 0          1         1    1    3      0      0     3        C    6     0
# 1          1         0    0    6      1      0     3        C  NaN     0
# 2          2         1    1    2      1      2     3        C   14     0
# 3          2         0    0    1      0      0     1        S  NaN     0
# 4          1         0    0    6      1      0     4        C  NaN   124
# ...      ...       ...  ...  ...    ...    ...   ...      ...  ...   ...
# 1043       3         0    1    4      0      0     0        Q  NaN     0
# 1044       3         0    1    1      0      0     0        S  NaN     0
# 1045       3         0    0    4      0      0     2        S  NaN    14
# 1046       3         1    1    3      0      0     0        S  NaN     0
# 1047       3         0    1    4      0      0     0        S  NaN     0
#
#       relatives  not_alone  Deck  Title
# 0             0          1     3      2
# ...

# %%
train_df['embarked'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1048 entries, 0 to 1047
# Series name: embarked
# Non-Null Count  Dtype
# --------------  -----
# 1048 non-null   object
# dtypes: object(1)
# memory usage: 8.3+ KB

# %%
unique_values = train_df['embarked'].unique()
unique_values
# Out:
# array(['C', 'S', 'Q'], dtype=object)

# %%
data = [train_df, test_df]

for dataset in data:
       dataset.dropna(subset=['embarked'], inplace=True)
       dataset['embarked'] = dataset['embarked'].map({'C': 0, 'S': 1, 'Q': 2})

# %%
train_df
# Out:
#       pclass  survived  sex  age  sibsp  parch  fare  embarked boat  body  \
# 0          1         1    1    3      0      0     3         0    6     0
# 1          1         0    0    6      1      0     3         0  NaN     0
# 2          2         1    1    2      1      2     3         0   14     0
# 3          2         0    0    1      0      0     1         1  NaN     0
# 4          1         0    0    6      1      0     4         0  NaN   124
# ...      ...       ...  ...  ...    ...    ...   ...       ...  ...   ...
# 1043       3         0    1    4      0      0     0         2  NaN     0
# 1044       3         0    1    1      0      0     0         1  NaN     0
# 1045       3         0    0    4      0      0     2         1  NaN    14
# 1046       3         1    1    3      0      0     0         1  NaN     0
# 1047       3         0    1    4      0      0     0         1  NaN     0
#
#       relatives  not_alone  Deck  Title
# ...

# %%
data = [train_df, test_df]

for dataset in data:
    dataset['Age_Class'] = dataset['age'] * dataset['pclass']

for dataset in data:
    dataset['fare_Per_Person'] = dataset['fare'] / (dataset['relatives'] + 1)
    dataset['fare_Per_Person'] = dataset['fare_Per_Person'].astype(int)

# %%
train_df
# Out:
#       pclass  survived  sex  age  sibsp  parch  fare  embarked boat  body  \
# 0          1         1    1    3      0      0     3         0    6     0
# 1          1         0    0    6      1      0     3         0  NaN     0
# 2          2         1    1    2      1      2     3         0   14     0
# 3          2         0    0    1      0      0     1         1  NaN     0
# 4          1         0    0    6      1      0     4         0  NaN   124
# ...      ...       ...  ...  ...    ...    ...   ...       ...  ...   ...
# 1043       3         0    1    4      0      0     0         2  NaN     0
# 1044       3         0    1    1      0      0     0         1  NaN     0
# 1045       3         0    0    4      0      0     2         1  NaN    14
# 1046       3         1    1    3      0      0     0         1  NaN     0
# 1047       3         0    1    4      0      0     0         1  NaN     0
#
#       relatives  not_alone  Deck  Title  Age_Class  fare_Per_Person
# ...

# %%
data = [train_df, test_df]

for dataset in data:
       dataset.dropna(subset=['boat'], inplace=True)

# %%
train_df=train_df.drop(['boat'],axis=1)
test_df=test_df.drop(['boat'],axis=1)

# %%
train_df
# Out:
#       pclass  survived  sex  age  sibsp  parch  fare  embarked  body  \
# 0          1         1    1    3      0      0     3         0     0
# 2          2         1    1    2      1      2     3         0     0
# 7          2         1    1    5      0      0     1         1     0
# 10         2         1    1    2      1      1     2         1     0
# 12         2         1    1    2      0      0     1         1     0
# ...      ...       ...  ...  ...    ...    ...   ...       ...   ...
# 1036       3         1    1    1      0      2     2         0     0
# 1037       1         1    0    3      0      0     2         1     0
# 1039       3         1    0    3      0      0     0         1     0
# 1041       1         1    1    4      1      0     4         1     0
# 1042       3         1    1    2      0      0     2         2     0
#
#       relatives  not_alone  Deck  Title  Age_Class  fare_Per_Person
# 0             0          1     3      2          3                3
# ...

# %% [markdown]
# ## Model

# %%
X_train = train_df.drop("survived", axis=1)
Y_train = train_df["survived"]
X_test=train_df.copy()

# %% [markdown]
# ## Logistic Regression

# %%
logregression=LogisticRegression()
logregression.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
Y_prediction=logregression.predict(X_train)
accuracy_log=round(logregression.score(X_train,Y_train)*100,2)

# %%
accuracy_log
# Out:
# 98.13

# %% [markdown]
# ## Decision Tree

# %%
decisiontree=DecisionTreeClassifier()
decisiontree.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
Y_prediction=decisiontree.predict(X_train)
accuracy_decision_tree=round(decisiontree.score(X_train,Y_train)*100,2)

# %%
accuracy_decision_tree
# Out:
# 99.2

# %% [markdown]
# ## Random Forest

# %%
random_forest=RandomForestClassifier(n_estimators=100)
random_forest.fit(X_train,Y_train)
# Out:
# RandomForestClassifier()

# %%
Y_prediction=random_forest.predict(X_train)
random_forest.score(X_train,Y_train)
accuracy_random_forest=round(random_forest.score(X_train,Y_train)*100,2)

# %%
accuracy_random_forest
# Out:
# 99.2

# %% [markdown]
# ## SVC

# %%
linear_svc = LinearSVC()
linear_svc.fit(X_train, Y_train)

Y_pred = linear_svc.predict(X_train)

accuracy_linear_svc = round(linear_svc.score(X_train, Y_train) * 100, 2)
# Out:
# C:\Users\haric\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
accuracy_linear_svc
# Out:
# 98.13

# %% [markdown]
# ## Comparing result

# %%
results = pd.DataFrame({
'Model': ['Support Vector Machines', 'Logistic Regression','Random Forest','Decision Tree'],
'Score': [accuracy_linear_svc,accuracy_log,accuracy_random_forest,accuracy_decision_tree]})
result_df = results.sort_values(by='Score', ascending=False)
result_df = result_df.set_index('Score')
result_df.head(9)
# Out:
#                          Model
# Score
# 99.20            Random Forest
# 99.20            Decision Tree
# 98.13  Support Vector Machines
# 98.13      Logistic Regression

# %% [markdown]
# ## Cross Validation

# %%
from sklearn.model_selection import cross_val_score
rf = RandomForestClassifier(n_estimators=100)
scores = cross_val_score(rf, X_train, Y_train, cv=10, scoring = "accuracy")
print("Scores:", scores)
print("Mean:", scores.mean())
print("Standard Deviation:", scores.std())
# Out:
# C:\Users\haric\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_split.py:700: UserWarning: The least populated class in y has only 7 members, which is less than n_splits=10.
#   warnings.warn(
# Scores: [0.97368421 0.94736842 0.94736842 0.97368421 0.97368421 1.
#  0.97297297 1.         0.94594595 0.97297297]
# Mean: 0.9707681365576104
# Standard Deviation: 0.018588897945356064

# %%
importances = pd.DataFrame({'feature':X_train.columns, 'importance':np.round(random_forest.feature_importances_,3)})
importances = importances. sort_values('importance',ascending=False).set_index('feature')
importances.head(15)
# Out:
#                  importance
# feature
# Age_Class             0.201
# age                   0.177
# fare_Per_Person       0.101
# fare                  0.089
# Title                 0.082
# relatives             0.058
# embarked              0.057
# pclass                0.056
# Deck                  0.045
# sibsp                 0.043
# sex                   0.038
# not_alone             0.030
# parch                 0.023
# body                  0.000

# %%
importances.plot.bar()
# Out:
# <AxesSubplot: xlabel='feature'>

# %% [markdown]
# ## Hyper Parameter tuning

# %%
random_forest = RandomForestClassifier(criterion = "gini",min_samples_leaf = 1,min_samples_split = 10,n_estimators=100,max_features='auto',oob_score=True,
random_state=1,n_jobs =- 1)

random_forest.fit(X_train, Y_train)
Y_prediction = random_forest.predict(X_train)

random_forest.score(X_train, Y_train)

print("oob score:", round(random_forest.oob_score_, 4)*100, "%")
# Out:
# C:\Users\haric\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# oob score: 98.13 %

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix
predictions = cross_val_predict(logregression, X_train, Y_train, cv=3)
confusion_matrix(Y_train, predictions)
# Out:
# array([[  0,   7],
#        [  0, 368]], dtype=int64)

# %%
from sklearn.metrics import precision_score, recall_score

print("Precision:", precision_score(Y_train, predictions))
print("Recall:", recall_score(Y_train, predictions))

# %%
from sklearn.metrics import *
f1_score(Y_train, predictions)

# %%
from sklearn.metrics import precision_recall_curve

# getting the probabilities of our predictions
y_scores = random_forest.predict_proba(X_train)
y_scores = y_scores[:,1]

precision, recall, threshold = precision_recall_curve(Y_train, y_scores)
def plot_precision_and_recall(precision, recall, threshold):
        plt.plot(threshold, precision[ :- 1], "r-", label="precision", linewidth=5)
        plt.plot(threshold, recall[ :- 1], "b", label="recall", linewidth=5)
        plt.xlabel("threshold", fontsize=19)
        plt.legend(loc="upper right", fontsize=19)
        plt.ylim([0, 1])

plt.figure()
plot_precision_and_recall(precision, recall, threshold)
plt.show()

# %%
from sklearn.metrics import roc_auc_score
r_a_score = roc_auc_score(Y_train, y_scores)
print("ROC-AUC-Score:", r_a_score)
# Out:
# ROC-AUC-Score: 0.9881599378881988
